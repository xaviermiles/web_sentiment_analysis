# %% [markdown]
# # Aim: identify shopping cart softwares within websites' HTML
#
# Ideal scenario: Use the top 100 (or so) websites for each cart software (source: https://builtwith.com/ecommerce/new-zealand/). This would automate collecting a large sample of websites to test and generate "actual"/baseline labels. However, this requires non-free plan.
#
# Solution: Use lists of websites and manually plug them into the BuiltWith website to see what "eCommerce" software they use. Because I am using lists of websites which use the given softwares, I may be biased in favour of testing websites which are easily classifiable (but this is unavoidable for now).

# %%
import os
import re
import urllib, requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

from fake_useragent import UserAgent

# %%
def make_url_name(url):
    """
    Return a name from the url, if it fails to make a nice name it will just return the url
    """
    netloc = urllib.parse.urlsplit(url).netloc
    netloc_pieces = netloc.split('.')
    
    if 'co' in netloc_pieces:
        i = netloc_pieces.index('co')
    elif 'com' in netloc_pieces:
        i = netloc_pieces.index('com')
    elif 'org' in netloc_pieces:
        i = netloc_pieces.index('org')
    elif 'nz' in netloc_pieces:
        i = netloc_pieces.index('nz')
    else:
        return netloc
    
    return netloc_pieces[i - 1]

# %%
# Source: BuiltWith.com
# '?' means that it was not showing on the Basic Technology View (detailed view may or may not show it[?])
# '!none' means that BuiltWith was unable to do lookups on the site

# There are multiple Squarespace plans that come up on BuiltWith, but I collated them under Squarespace
# Bold UpSell = Shopify, since it is a Shopify app
# Shopify Plus = Shopify, since it is a Shopify plan
# WooCommerce Checkout = WooCommerce, since I think they mean the same thing
# Magento Enterprise = Magento, since it is a Magento plan
actual = {
    'http://macpac.co.nz/': ['Demandware', 'Salesforce Commerce Cloud'],
    'https://www.huffer.co.nz/': ['Magento'],
    'https://www.allbirds.co.nz': ['Shopify'],
    'https://infinitedefinite.com/': ['Shopify'],
    'https://www.hallensteins.com/': ['?'],
    'https://www.glassons.com/nz': ['?'],
    'https://www.barkersonline.co.nz/': ['Magento'],
#     'https://www.maxshop.com/',  # no SSL certificate
    'https://shop.countdown.co.nz/': ['custom'],
    'https://www.barkers.co.nz/': ['WooCommerce'],
    'https://www.picspeanutbutter.com/nz/': ['?'],
    'https://rainbowconfectionery.co.nz/': ['Magento'],
    'https://www.mountainwarehouse.com/nz/': ['?'],
    'https://www.kathmandu.co.nz/': ['Magento'],
    'https://cottonon.com/NZ/': ['Salesforce Commerce Cloud', 'Demandware'],
    'https://www.platypusshoes.co.nz/': ['Magento'],
    
    # https://www.moneyhub.co.nz/online-shopping.html
    # > clothing
    'https://designerwardrobe.co.nz/': ['?'],
    'https://www.princesspolly.com.au/?currency=NZD': ['Shopify'],
    'https://www.surfstitch.com/nz/': ['Salesforce Commerce Cloud', 'Demandware'],
    'https://www.missguidedau.com/': ['Magento', 'Amplience'],
    'https://www.bonds.com.au/': ['Magento'],
    'https://www.ezibuy.com/shop/nz/': ['SAP Commerce Cloud'],
    'https://www.onceit.co.nz/': ['custom'],
    'https://www.merchant1948.co.nz/': ['Magento'],
    'https://www.justjeans.co.nz/': ['Kibo', 'HCL Commerce'],
    'https://allaboutagirl.co.nz/': ['Shopify'],
    'https://www.kidrepublic.co.nz/': ['custom'],
    'https://nz.boohoo.com/': ['Salesforce Commerce Cloud', 'Amplience', 'Demandware'],
    'https://www.superette.co.nz/': ['?'],
    'https://www.mode.co.nz/': ['CS Cart'],
    'https://www.prettylittlething.com.au/': ['Magento', 'Kibo'],
    'https://www.showpo.com/nz/': ['Salesforce Commerce Cloud', 'Demandware'],
    'https://www.farfetch.com/nz/': ['?'],
    'http://www.asos.com/': ['custom'],
    'https://www.zara.com/nz/': ['?'],
    # > beauty products
    'https://strawberrynet.com/en-us/': ['?'],
    'https://www.lovemymakeup.co.nz/': ['Shopify'],
    'https://nz.iherb.com/': ['?'],
    'https://beautybliss.co.nz/': ['?'],
    'https://www.sephora.nz/': ['custom'],
    # > sports
    'https://www.torpedo7.co.nz/': ['custom'],
    'https://www.rebelsport.co.nz/': ['?'],
    'https://www.nike.com/nz/': ['?'],
    'https://www.kathmandu.co.nz/': ['Magento'],
    # > general homeware/department store
    'https://www.thewarehouse.co.nz/': ['Demandware', 'Salesforce Commerce Cloud'],
    'https://www.kmart.co.nz/': ['HCL Commerce'],
    'https://www.farmers.co.nz/': ['Intershop'],
    'https://www.harveynorman.co.nz/': ['CS Cart'],
    'https://www.budgetbeds.co.nz/': ['OpenCart'],
    'https://www.catch.co.nz/': ['custom'],
    'https://www.toyco.co.nz/': ['custom'],
    # > computer & tech
    'https://www.noelleeming.co.nz/': ['Powerfront'],
    'https://www.pbtech.co.nz/': ['custom'],
    'https://www.jbhifi.co.nz/': ['custom'],
    'https://www.ebgames.co.nz/': ['custom'],
    'https://www.dicksmith.co.nz/': ['?'],
    # > auction/marketplace
    'https://www.etsy.com/': ['custom'],
    'https://www.aliexpress.com/': ['custom'],
#     'https://www.ebay.com/': ['!none'],  # VERY strict policy on bots
#     'https://www.ebay.com.au/': ['custom'],
    'https://www.amazon.com/': ['Amazon Webstore'],
    'https://www.wish.com/': ['?'],
    'https://www.1-day.co.nz/': ['custom'],
    'https://themarket.com/nz/': ['?'],
    'https://www.trademe.co.nz/': ['custom'],
    'https://www.mightyape.co.nz/': ['custom'],
    # > misc
    'https://www.skechers.co.nz/': ['Magento'],
    'https://www.notsocks.co.nz/': ['BigCommerce'],
    'https://www.supercheapauto.co.nz/': ['Demandware', 'Salesforce Commerce Cloud'],
    'https://www.repco.co.nz/': ['SAP Commerce Cloud'],
    'https://www.bunnings.co.nz/': ['Powerfront', 'Sitecore Experience Commerce'],
    'https://www.mitre10.co.nz/': ['SAP Commerce Cloud'],
    'https://www.warehousestationery.co.nz/': ['Demandware', 'Salesforce Commerce Cloud'],
    'https://www.fishpond.co.nz/': ['osCommerce'],
    'https://www.vistaprint.co.nz/': ['custom'],
    'https://www.plasticmodels.co.nz/': ['custom'],
    'https://www.diecastmodels.co.nz/': ['custom'],
    
    # https://woocommerce.com/posts/12-great-examples-woocommerce-stores/ - fairly out-of-date but oh well
    'https://www.jhornig.com/': ['WooCommerce'],
    'https://porterandyork.com/': ['WooCommerce'],
    'https://cupcake.com.ua/': ['?'],
    'https://www.dineamic.com.au/': ['Shopify'],
    'http://buddhibaby.ca/': ['?'],
    'https://ecokitty.co.uk/': ['WooCommerce'],
    'https://pickybars.com/': ['Shopify'],
    'https://fitgersbrewhouse.com/': ['Squarespace'],
    'https://bestfive.com.au/': ['!none'],
    'https://overclothing.com/': ['WooCommerce'],
    
    # https://blog.hubspot.com/marketing/best-shopify-stores
    'https://ugmonk.com/': ['Shopify'],
    'https://www.pipsnacks.com/': ['Shopify'],
    'https://www.taylorstitch.com/': ['Shopify'],
    'https://www.happinessabscissa.com/': ['Shopify'],
    'https://www.burga.com/': ['Shopify'],
    'https://skinny-teatox.com/': ['Shopify'],
    'https://helmboots.com/': ['Shopify'],
    'https://www.bioliteenergy.com/': ['Shopify'],
    'https://www.popchartlab.com/': ['Shopify'],
    'https://lucadanni.com/': ['Shopify'],
    'https://www.harrisfarm.com.au/': ['Shopify'],
    'https://www.greatgeorgewatches.com/': ['Shopify'],
    'http://www.choosemuse.com/': ['Shopify'],
    'https://brilliant.org/': ['?'],
    'https://www.holstee.com/': ['Shopify'],
    'https://www.kyliecosmetics.com/': ['Shopify'],
    
    # https://www.zfort.com/blog/top-10-magento-ecommerce-websites
    'https://www.joelandsonfabrics.com/': ['Magento'],
    'https://www.sigmabeauty.com/': ['Magento'],
    'https://www.coxandcox.co.uk/': ['Magento'],
    'https://www.boodles.com/': ['Magento'],
    'https://www.thenewcraftsmen.com/': ['Magento'],
    'https://www.warbyparker.com/': ['?'],
    'https://www.swellbottle.com/': ['WooCommerce'],
    'https://www.fredperry.com/': ['Magento'],
    'https://www.hellyhansen.com/': ['Magento', 'Kibo'],
    
    # https://winningwp.com/examples-of-websites-using-squarespace/
    'http://www.newinc.org/': ['Squarespace'],
    'http://www.aplusi.com/': ['?'],
    'https://fightingeel.com/': ['Squarespace'],
    'http://darrenbooth.com/': ['Squarespace'],
    'http://www.picathingswelove.com/': ['Squarespace'],
    'http://corp.bandsintown.com/': ['Squarespace'],
    'http://thehatchinstitute.org/': ['?'],  # for these sites, squarespace was under 'Content Management System'
    'http://aldernyc.com/': ['?'],
    'https://thechicks.com/': ['?'],
    'http://www.tianstudios.com/': ['Squarespace'],
    'http://www.corcellars.com/': ['?'],
    'http://www.liftedlandscape.com/': ['Squarespace'],
    'http://betatakaki.com/': ['?'],
    'http://bluedognyc.com/': ['?'],
    
    # https://www.wix.com/blog/ecommerce/2018/10/ecommerce-website-design-examples
    'https://www.coalandcanary.com/': ['Wix Stores', 'Ecwid'],
    'https://www.ultasmile.com/': ['Wix Stores'],
    'https://www.evolveclothinggallery.com/': ['Wix Stores'],
    'https://www.thespicesuite.com/': ['Wix Stores'],
    'https://www.kaekoo.com/': ['Wix Stores'],
    'https://www.rubylove.com/': ['Wix Stores'],
    'https://www.celiab.com/': ['Wix Stores'],
    # https://superbwebsitebuilders.com/wix-ecommerce-examples-online-stores-shops/
    'https://www.drysteppers.com/': ['Shopify'],
    'http://www.piece-of-history.com/': ['Wix Stores'],
    'https://www.vintique-watch.com/': ['?'],
    'https://www.originalteatowel.co.uk/': ['Wix Stores'],
    'http://www.bensimonboutique.com/': ['Wix Stores'],
    'https://www.amoodz.com/': ['Wix Stores'],
    'http://www.smallchangefinery.com/': ['Wix Stores'],
    'https://www.andreamirandasalas.com/': ['Wix Stores'],
#     'https://www.lefayeproducts.com/': ['Wix Stores', 'Ecwid'],  # domain for sale
    'https://www.claycrocks.com/': ['?'],
    'https://www.kerripom.com/': ['Wix Stores'],
    'https://www.kimweitkamp.com/': ['?'],
    'https://www.tarotbyseven.com/': ['Wix Stores', 'Ecwid'],
    'https://www.theguitarhanger.com/': ['Wix Stores'],
}

print(f"Recheck with BuiltWith detailed view:\n{[make_url_name(site) for site, cart_software in actual.items() if cart_software == ['?']]}")
# Out:
# Recheck with BuiltWith detailed view:
# ['hallensteins', 'glassons', 'picspeanutbutter', 'mountainwarehouse', 'designerwardrobe', 'superette', 'farfetch', 'zara', 'strawberrynet', 'iherb', 'beautybliss', 'rebelsport', 'nike', 'dicksmith', 'wish', 'themarket', 'cupcake', 'buddhibaby.ca', 'brilliant', 'warbyparker', 'aplusi', 'thehatchinstitute', 'aldernyc', 'thechicks', 'corcellars', 'betatakaki', 'bluedognyc', 'vintique-watch', 'claycrocks', 'kimweitkamp']

# %%
def cart_software_detector(html):
    """
    The commented-out detectors are old versions that worked very well, but 
    not quite as well as their replacement.
    """
    bs = BeautifulSoup(html)
    ecom = []
        
    # Demandware is a subsidiary of Salesforce and was renamed to Salesforce Commerce Cloud
    if any('demandware' in tag['src'] for tag in bs.find_all('img', {'src': True})):
        ecom.append('Demandware')
        
    if bs.find('script', attrs={'type': 'text/x-magento-init'}) is not None:
        ecom.append('Magento')
        
    if bs.find('span', attrs={'class': 'nosto_cart'}) is not None:
        ecom.append('nosto')
        
#     if any('var Shopify =' in script.string for script in bs.find_all('script') if script.string]):
#         ecom.append('Shopify')
    if any('shopify' in tag['href'] for tag in bs.find_all('link', {'rel': 'stylesheet', 'href': True})):
        ecom.append('Shopify')
        
    sitecore_detector = any('sitecore-link-wrapper' in tag['class'] for tag in bs.find_all('div', {'class': True}))
    if sitecore_detector or 'SITECORE_APIKEY' in str(bs):
        ecom.append('Sitecore Experience Commerce')
        
    if bs.find('link', {'rel': 'preconnect', 'href': 'https://images.squarespace-cdn.com'}) is not None:
        ecom.append('Squarespace')
        
    # These two Wix detections work perfectly/identically on the testing websites, so I left just the computationally cheapest
    if bs.find('meta', {'name': 'generator', 'content': 'Wix.com Website Builder'}) is not None:
        ecom.append('Wix Stores')
#     elif any('static.parastorage.com' in tag['src'] for tag in bs.find_all('script', {'src': True})):
#         ecom.append('Wix Stores')
        
#     woocommerce_script_detector = ['woocommerce' in tag['src'] for tag in bs.find_all('script', {'src': True})]
#     if True in woocommerce_script_detector:
#         ecom.append('WooCommerce')
#     woocommerce_link_detector = ['woocommerce' in tag['id'] for tag in bs.find_all('link', {'rel': 'stylesheet', 'id': True})]
#     if True in woocommerce_link_detector:
#         ecom.append('WooCommerce')
    if bs.find('style', {'id': 'woocommerce-inline-inline-css', 'type': 'text/css'}) is not None:
        ecom.append('WooCommerce')
        
    return ecom

# %%
html_folder = "test_scraping_html"
site_to_html = dict()
scrape_errors = dict()

OVERWRITE_HTML_FILES = False

ua = UserAgent() # pretend to be Chrome user

for url in actual.keys():
    try:
        fpath = os.path.join(html_folder, f"{make_url_name(url)}.html")
        
        if not os.path.exists(fpath) or OVERWRITE_HTML_FILES:   
            r = requests.get(url, timeout=20, headers={'User-Agent': ua.chrome})
            html = r.content.decode()
            with open(fpath, 'w') as f:
                f.write(html)
        else: 
            with open(fpath, 'r') as f:
                html = f.read()
            
        site_to_html[url] = html
        
    except Exception as e:
        error_name = type(e).__name__
        print(f"{error_name}: {url}")
        scrape_errors[url] = error_name
# Out:
# UnicodeDecodeError: https://www.pbtech.co.nz/
# SSLError: https://www.vintique-watch.com/

# %%
pred = {
    site: cart_software_detector(html) for site, html in site_to_html.items()
}

robotblocks = [
    'https://www.repco.co.nz/'
    'https://kmart.co.nz/',
    'https://www.ebgames.co.nz/',
    'https://www.dicksmith.co.nz/',
    'https://www.amazon.com/',
]
for site in robotblocks:
    scrape_errors[site] = "robotblock"

results = pd.DataFrame(
    [(make_url_name(site), site, actual[site], pred.get(site, "")) for site in actual.keys()],
    columns=['name', 'url', 'BuiltWith', 'pred']
)

results['Correct'] = [actual == pred if actual != ['?'] else "" 
                      for actual, pred in zip(results['BuiltWith'], results['pred'])]
results['Partial_correct'] = [len(set(actual).intersection(set(pred))) > 0 if actual != ['?'] else ""
                              for actual, pred, in zip(results['BuiltWith'], results['pred'])]  # check for any overlap
results['Exception'] = [scrape_errors.get(site, "") for site in results['url']]

results.to_csv("results/test_scraping_results.csv")
results
# Out:
#                  name                               url  \
# 0              macpac              http://macpac.co.nz/
# 1              huffer         https://www.huffer.co.nz/
# 2            allbirds        https://www.allbirds.co.nz
# 3    infinitedefinite     https://infinitedefinite.com/
# 4        hallensteins     https://www.hallensteins.com/
# ..                ...                               ...
# 137        claycrocks       https://www.claycrocks.com/
# 138          kerripom         https://www.kerripom.com/
# 139       kimweitkamp      https://www.kimweitkamp.com/
# 140      tarotbyseven     https://www.tarotbyseven.com/
# 141   theguitarhanger  https://www.theguitarhanger.com/
#
#                                    BuiltWith          pred Correct  \
# 0    [Demandware, Salesforce Commerce Cloud]  [Demandware]   False
# 1                                  [Magento]     [Magento]    True
# 2                                  [Shopify]     [Shopify]    True
# 3                                  [Shopify]     [Shopify]    True
# 4                                        [?]            []
# ..                                       ...           ...     ...
# 137                                      [?]  [Wix Stores]
# 138                             [Wix Stores]  [Wix Stores]    True
# 139                                      [?]  [Wix Stores]
# 140                      [Wix Stores, Ecwid]  [Wix Stores]   False
# 141                             [Wix Stores]  [Wix Stores]    True
#
#     Partial_correct Exception
# 0              True
# 1              True
# 2              True
# 3              True
# 4
# ..              ...       ...
# 137
# 138            True
# 139
# 140            True
# 141            True
#
# [142 rows x 7 columns]

# %% [markdown]
# ## Check Results
#
# Note that these results do not consider *implied* cart software. For example:
#
# - I know that 'Salesforce Commerce Cloud' is a different name for 'Demandware' but I have not coded this logic.
# - I am 80% certain that the presence of 'nosto' implies 'Magento' but I have not coded this logic (because I'm not 100% sure).
# - I think 'WooCommerce Checkout' is redundant, and 'WooCommerce' would suffice.
# - 'Shopify Plus' is a more expensive plan of 'Shopify', I don't know if it's necessary to distinguish these.

# %%
performance = pd.DataFrame({'software': sorted(set(results['BuiltWith'].sum()))})
performance['BuiltWith'] = [sum([software in x for x in results['BuiltWith']]) for software in performance['software']]
performance['true_pos'] = [sum([software in actual and software in pred for actual, pred in zip(results['BuiltWith'], results['pred'])]) 
                           for software in performance['software']]
performance['false_pos'] = [sum([software not in actual and software in pred for actual, pred in zip(results['BuiltWith'], results['pred'])]) 
                            for software in performance['software']]

performance.to_csv("results/test_scraping_performance.csv")
performance[performance['BuiltWith'] > 1]  # filter so it's not as cluttered
# Out:
#                      software  BuiltWith  true_pos  false_pos
# 1                           ?         30         0          0
# 3                   Amplience          2         0          0
# 5                     CS Cart          2         0          0
# 6                  Demandware          8         8          0
# 7                       Ecwid          2         0          0
# 8                HCL Commerce          2         0          0
# 10                       Kibo          3         0          0
# 11                    Magento         17        11          0
# 13                 Powerfront          2         0          0
# 14         SAP Commerce Cloud          3         0          0
# 15  Salesforce Commerce Cloud          8         0          0
# 16                    Shopify         23        23          0
# 18                Squarespace          8         8          6
# 19                 Wix Stores         16        16          2
# 20                WooCommerce          6         6          0
# 21                     custom         19         0          0

# %% [markdown]
# ## Testing

# %%
# See sites which have Wix Stores as actual OR predicted
wix_mask = [
    'Wix Stores' in actual + pred if pred != ""
    else 'Wix Stores' in actual
    for actual, pred in zip(results['BuiltWith'], results['pred'])
]
results[wix_mask]
# Out:
#                       name                                     url  \
# 122          coalandcanary          https://www.coalandcanary.com/
# 123              ultasmile              https://www.ultasmile.com/
# 124  evolveclothinggallery  https://www.evolveclothinggallery.com/
# 125          thespicesuite          https://www.thespicesuite.com/
# 126                 kaekoo                 https://www.kaekoo.com/
# 127               rubylove               https://www.rubylove.com/
# 128                 celiab                 https://www.celiab.com/
# 130       piece-of-history        http://www.piece-of-history.com/
# 132       originalteatowel     https://www.originalteatowel.co.uk/
# 133       bensimonboutique        http://www.bensimonboutique.com/
# 134                 amoodz                 https://www.amoodz.com/
# 135      smallchangefinery       http://www.smallchangefinery.com/
# 136     andreamirandasalas     https://www.andreamirandasalas.com/
# 137             claycrocks             https://www.claycrocks.com/
# 138               kerripom               https://www.kerripom.com/
# 139            kimweitkamp            https://www.kimweitkamp.com/
# 140           tarotbyseven           https://www.tarotbyseven.com/
# 141        theguitarhanger        https://www.theguitarhanger.com/
#
#                BuiltWith          pred Correct Partial_correct Exception
# 122  [Wix Stores, Ecwid]  [Wix Stores]   False            True
# 123         [Wix Stores]  [Wix Stores]    True            True
# 124         [Wix Stores]  [Wix Stores]    True            True
# 125         [Wix Stores]  [Wix Stores]    True            True
# 126         [Wix Stores]  [Wix Stores]    True            True
# 127         [Wix Stores]  [Wix Stores]    True            True
# 128         [Wix Stores]  [Wix Stores]    True            True
# 130         [Wix Stores]  [Wix Stores]    True            True
# 132         [Wix Stores]  [Wix Stores]    True            True
# 133         [Wix Stores]  [Wix Stores]    True            True
# 134         [Wix Stores]  [Wix Stores]    True            True
# 135         [Wix Stores]  [Wix Stores]    True            True
# 136         [Wix Stores]  [Wix Stores]    True            True
# 137                  [?]  [Wix Stores]
# 138         [Wix Stores]  [Wix Stores]    True            True
# 139                  [?]  [Wix Stores]
# 140  [Wix Stores, Ecwid]  [Wix Stores]   False            True
# 141         [Wix Stores]  [Wix Stores]    True            True

# %%
for site in results[['Wix Stores' in x for x in results['BuiltWith']]]['url']:
    print(site)
    bs = BeautifulSoup(site_to_html[site])
    
    print(bs.find('meta', {'name': 'generator', 'content': 'Wix.com Website Builder'}) is not None)
#     print('static.parastorage.com' in site_to_html[site].lower())
    print(any('static.parastorage.com' in tag['src'] for tag in bs.find_all('script', {'src': True})))
    print('wix.com' in site_to_html[site].lower())
# Out:
# https://www.coalandcanary.com/
# True
# True
# True
# https://www.ultasmile.com/
# True
# True
# True
# https://www.evolveclothinggallery.com/
# True
# True
# True
# https://www.thespicesuite.com/
# True
# True
# True
# https://www.kaekoo.com/
# True
# True
# True
# https://www.rubylove.com/
# True
# True
# True
# https://www.celiab.com/
# True
# True
# True
# http://www.piece-of-history.com/
# True
# True
# True
# https://www.originalteatowel.co.uk/
# True
# True
# True
# http://www.bensimonboutique.com/
# True
# True
# True
# https://www.amoodz.com/
# True
# True
# True
# http://www.smallchangefinery.com/
# True
# True
# True
# https://www.andreamirandasalas.com/
# True
# True
# True
# https://www.kerripom.com/
# True
# True
# True
# https://www.tarotbyseven.com/
# True
# True
# True
# https://www.theguitarhanger.com/
# True
# True
# True

# %%
# See which sites have custom cart software
results[['custom' in x for x in results['BuiltWith']]]
# Out:
#              name                               url BuiltWith pred Correct  \
# 7       countdown     https://shop.countdown.co.nz/  [custom]   []   False
# 21         onceit         https://www.onceit.co.nz/  [custom]   []   False
# 25    kidrepublic    https://www.kidrepublic.co.nz/  [custom]   []   False
# 32           asos              http://www.asos.com/  [custom]   []   False
# 38        sephora           https://www.sephora.nz/  [custom]   []   False
# 39       torpedo7       https://www.torpedo7.co.nz/  [custom]   []   False
# 47          catch          https://www.catch.co.nz/  [custom]   []   False
# 48          toyco          https://www.toyco.co.nz/  [custom]   []   False
# 50         pbtech         https://www.pbtech.co.nz/  [custom]        False
# 51         jbhifi         https://www.jbhifi.co.nz/  [custom]   []   False
# 52        ebgames        https://www.ebgames.co.nz/  [custom]   []   False
# 54           etsy             https://www.etsy.com/  [custom]   []   False
# 55     aliexpress       https://www.aliexpress.com/  [custom]   []   False
# 58          1-day          https://www.1-day.co.nz/  [custom]   []   False
# 60        trademe        https://www.trademe.co.nz/  [custom]   []   False
# 61      mightyape      https://www.mightyape.co.nz/  [custom]   []   False
# 70     vistaprint     https://www.vistaprint.co.nz/  [custom]   []   False
# 71  plasticmodels  https://www.plasticmodels.co.nz/  [custom]   []   False
# 72  diecastmodels  https://www.diecastmodels.co.nz/  [custom]   []   False
#
#    Partial_correct           Exception
# 7            False
# 21           False
# 25           False
# 32           False
# 38           False
# 39           False
# 47           False
# 48           False
# 50           False  UnicodeDecodeError
# 51           False
# 52           False          robotblock
# 54           False
# 55           False
# 58           False
# 60           False
# 61           False
# 70           False
# 71           False
# 72           False

# %%
for site in results[['custom' in x for x in results['BuiltWith']]]['url']:
    if site in scrape_errors:
        continue
    
    print(site)
    bs = BeautifulSoup(site_to_html[site])
    
    print([tag['title'] for tag in bs.find_all('a', {'title': True}) if 'cart' in tag['title'].lower()])
    print([tag_class for tag in bs.find_all('div', {'class': True}) for tag_class in tag['class'] if 'cart' in tag_class])
    print()
    
    print([tag['id'] for tag in bs.find_all('div', {'id': True}) ])#if 'minicart' in tag['id'].lower()])
    print()
# Out:
# https://shop.countdown.co.nz/
# []
# []
#
# []
#
# https://www.onceit.co.nz/
# ['Link to shop the The Others, Cartel and More - New Restock! sale']
# []
#
# []
#
# https://www.kidrepublic.co.nz/
# ['Shopping Cart']
# ['cart_qty_img']
#
# ['bodywrapper', 'ctl00_divHeader', 'ctl00_HeaderTop_pnlContentContainerData', 'ctl00_HeaderTop_Content_162_pnlContentData', 'ctl00_HeaderTop_Content_180_pnlContentData', 'ctl00_HeaderTop_Content_163_pnlContentData', 'ctl00_HeaderTop_Content_3_pnlContentContainerData', 'ctl00_HeaderTop_Content_3_Content_25_pnlContentData', 'ctl00_HeaderMiddle_pnlContentContainerData', 'ctl00_HeaderMiddle_Content_192_pnlContentData', 'ctl00_HeaderMiddle_Content_23_pnlContentContainerData', 'ctl00_HeaderMiddle_Content_23_Content_5_pnlContentData', 'ctl00_HeaderMiddle_Content_23_Content_5_dvMenu', 'mainMenuSearchBar', 'mainMenuNavigationBar', 'ctl00_HeaderBottom_pnlContentContainerData', 'ctl00_tdCentre', 'ctl00_MainCentre_container_pnlContentContainerData', 'ctl00_MainCentre_container_Content_183_pnlContentData', 'wowslider-container1', 'ctl00_MainCentre_container_Content_191_pnlContentData', 'ctl00_MainCentre_container_Content_219_pnlContentData', 'ctl00_MainCentre_container_Content_263_pnlContentData', 'ctl00_MainCentre_container_Content_210_pnlContentContainerData', 'ctl00_divFooter', 'ctl00_FooterTop_pnlContentContainerData', 'ctl00_FooterMiddle_pnlContentContainerData', 'ctl00_FooterMiddle_Content_108_pnlContentData', 'ctl00_FooterBottom_pnlContentContainerData', 'ctl00_FooterBottom_Content_17_pnlContentData', 'popupContent']
#
# http://www.asos.com/
# []
# []
#
# ['analytics', 'chrome-main-content', 'chrome-welcome-mat', 'chrome-header', 'chrome-sticky-header', 'myAccountDropdown', 'myaccount-dropdown', '5f867ce2-47e9-4e43-8ed6-84345c661780', '1020946c-8949-4e9c-9719-43435002bcd4', 'c1d265ba-f30e-4aaf-9966-1fa92bc544da', '96b432e3-d374-4293-8145-b00772447cde', '0edf7894-4f2f-42fb-896d-3e91a01704b1', '415ffca1-8c1a-48a7-8997-9cc4929a7134', '35ff0694-3b9d-43ff-b3a8-aea994d09a8c', 'b2164f1d-48aa-417d-9d1a-5cffa7eb1bb2', 'b690737b-bd19-4d49-83e4-e3ca6986fb65', '796c1478-6471-4acf-a952-049a9154b668', 'a92844a0-3b5b-41b6-ad85-9ca81f5c24f1', '58b7bec6-2318-4e4e-a97d-e5acdb8cb269', '9f9dffc5-6aa9-48a4-84c5-4f89ca92d511', '029c47b3-2111-43e9-9138-0d00ecf0b3db', '495d8469-0139-4a1b-8846-4cf56d142081', 'e87ba617-daa1-4b64-8f36-ab92e61283f7', '87a52035-f6fa-401f-bd58-0d259e403cbb', '0502a9b2-d1e8-4b34-9741-1141607c715e', '52a6e67d-76b9-44ce-8620-3dae31bacdfa', 'c51a4a82-3055-436d-8a41-6621fd7439aa', 'e5b71413-6f8c-4957-8ff1-67620c1db627', '03b93067-d1b1-44c4-9301-37479c7217cb', 'c42067f4-5f16-440a-ab2f-5163739caf68', 'a3ed6672-26b2-486b-88d1-b874034f0fd6', 'sc-sticky-header-portal', 'chrome-breadcrumb', 'chrome-footer', 'chrome-info-banner', 'chrome-modal-content', 'chrome-modal-container']
#
# https://www.sephora.nz/
# []
# ['cart-dropdown', 'cart', 'cart-dropdown-content']
#
# ['__nuxt', '__layout', 'dy-header-banner', 'dy-home-index-carousel-web']
#
# https://www.torpedo7.co.nz/
# ['Cart', 'cart']
# ['m-header__icons--cart', 'm-mini-cart__wrap', 'js-cart-quantity', 'm-mini-cart', 'JScart', 'm-header__icons--cart', 'error_cart_messages']
#
# ['browser-message', 'minicartholder', 'mini-cart', 'm-nav', 'global_strip_promo', 'shop-mobilemenu', 'data-dy-reorder', 'autocompleteContent', 'defaultACContent', 'search-overlay-content', 'browseHistoryAdvertDiv', 'video-popup', 'video-popup-holder', 'subscribedForm', 'athsWrap', 'athsWrap', 'login-popup', 'join-popup', 'forgotpassword-popup']
#
# https://www.catch.co.nz/
# []
# []
#
# ['__next', 'top-header', 'primary-header', 'header-messages', 'loginModal', 'login-container', 'clubCatchExclusive', 'clubCatchProductModal', 'google-trusted-store', 'bottomAd']
#
# https://www.toyco.co.nz/
# []
# []
#
# ['curtain', 'wrapper', 'ageError', 'homePriceSlider', 'catError']
#
# https://www.jbhifi.co.nz/
# ['Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart', 'Add to cart']
# []
#
# ['page_view', 'products_menu', 'store_finder', 'my_account', 'login_panel', 'logout_panel', 'product-search', 'recent-searches', 'cart', 'cartSummaryPanel', 'emptyCart', 'loadingCart', 'banner', 'main', 'ads-content-area-35', 'ads-content-area-36', 'ads-content-area-42', 'ads-content-area-39', 'ads-content-area-43', 'ads-content-area-37', 'ads-content-area-38', 'footer_social', 'footer_menu', 'footer_legal', 'search-overlay', 'results-bar', 'facets-dt', 'range-input', 'MainContent_products_jbProductListNoResults_noResult', 'facets-mob', 'facets-hammer', 'range-input', 'modal_view', 'NoCookies', '']
#
# https://www.etsy.com/
# []
# []
#
# ['fb-root', 'gdpr-privacy-settings', 'gnav-header', 'global-enhancements-search-suggestions', 'mobile-catnav-overlay', 'desktop-category-nav', 'javascript-nag', 'content', '', 'google-one-tap-modal-div', 'locale_overlay_container', 'collage-footer', 'g-recaptcha-etsy-public_email_subscribe-score', 'email-list-signup-invalid-email', 'email-list-signup-generic-error', 'wt-locale-picker-overlay', 'locale_picker_region_code', 'locale_picker_language_code', 'locale_picker_currency_code', 'etsy-modal-container']
#
# https://www.aliexpress.com/
# []
# ['nav-cart', 'nav-cart-box', 'right-shopcart']
#
# ['cross_page_common', 'j-aliexpress-notice', 'j-site-download-header', 'top-lighthouse', 'nav-global', 'nav-user-account', 'header', 'header-categories', 'search-cate', 'root']
#
# https://www.1-day.co.nz/
# []
# []
#
# ['app', 'main']
#
# https://www.trademe.co.nz/
# []
# []
#
# ['top-of-page', 'SiteHeader_Sitenav_SiteNavDiv', 'container', 'serverTime', 'siteClock', 'SiteHeader_SiteTabs_MyTradeMeDropDownBody', 'mtm-buying', 'agent-listings', 'mtm-selling', 'agent-reporting', 'mtm-account-info', 'SiteHeader_SiteTabs_BookACourierDropdownPromo', 'NotLoggedInDiv', 'SiteNavigation', 'SiteHeader_SiteTabs_BarOfSearch_SearchBarDiv', 'SiteHeader_SiteTabs_BarOfSearch_SearchBarInnerDiv', 'SiteHeader_SiteTabs_BarOfSearch_mainSearchControl', 'search-options-dropdown', 'watchlist-toggle-extension', 'watchlist-toggle-extension-line', 'SiteHeader_SiteTabs_BarOfSearch_watchlistDropdownToggleDiv', 'FavouritesToggle-extension', 'FavouritesToggle-extension-line', 'Main', 'mainContent', 'HomePageAnnouncementSpot', 'WelcomeHeader', 'HeaderCatSplat', 'CatSplat', 'verticals-feature', 'main-box-categories', 'main-box-jobs', 'jobsDistrictsLocationDiv', 'jobsSecondTierCategoryDiv', 'salaryRangePanel', 'hourlyRangePanel', 'SearchTabs1_JobsSearchFormControl_jobsWorkExperienceContainer', 'main-box-motors', 'MotorsNewCarModelDiv', 'HomePageSecondaryAnnouncementSpot', 'BillboardAd', 'OneDollarReserveStripe', 'watchlist3108412304', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl00_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl00_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl00_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl00_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3108412699', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl01_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl01_CarouselCard_BidInfo_listingBidPrice', 'watchlist3109765268', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl02_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl02_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl02_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl02_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3108413175', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl03_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl03_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl03_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl03_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3109765652', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl04_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl04_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl04_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl04_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3108413339', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl05_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl05_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl05_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl05_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3108413791', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl06_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl06_CarouselCard_BidInfo_listingBidPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl06_CarouselCard_BuyNow_listingBuyNowPrice', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl06_CarouselCard_BuyNow_listingBuyNowText', 'watchlist3108413924', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl07_CarouselCard_BidInfo_listingBidText', 'OneDollarReserveStripe_Buckets_ctl00_BucketCards_ctl07_CarouselCard_BidInfo_listingBidPrice', 'watchlist3108413935', 'On ...
#
# https://www.mightyape.co.nz/
# []
# []
#
# ['navDepartmentsMenu', 'navDepartmentMenu_Departments', 'navDepartmentMenu_HotDeals', 'navDepartmentMenu_gift-ideas-and-vouchers', 'navDepartmentMenu_customer-service', 'noticesContainer', 'skinPanelContainer', 'skinLeftPanel', 'skinRightPanel', 'div-gpt-ad-skin-0', 'adultContentModal', 'newsletterNagModal', 'page-state', 'fb-root', 'mightyape-chat-app']
#
# https://www.vistaprint.co.nz/
# []
# ['site-header-link-cart', 'cart-item-count-container', 'cart-item-count', 'cart-icon', 'cart-label']
#
# ['___gatsby', 'gatsby-focus-wrapper', 'target-container', 'vatSelectionPop', 'vatPopExclusiveLabel', 'vatPopInclusiveLabel', 'siteHeaderAccountMFEContainer', 'bookendsCountrySelectorContainer', 'gatsby-announcer']
#
# https://www.plasticmodels.co.nz/
# ['Add "I Love Kit 1/24 Fokker Dr.I" to your cart', 'Add "I Love Kit 1/24 Spad S.XIII" to your cart', 'Add "HobbyBoss 1/72 F4F-4 "Wildcat"" to your cart', 'Add "Revell Contacta Cement Tube 13g" to your cart']
# ['shop-cart']
#
# ['sidecart', 'Form_search_q_Holder', 'Form_search_ParentID_Holder', 'Form_search_ScaleID_Holder', 'Form_search_ManufacturerID_Holder', 'mc_embed_signup', 'mc_embed_signup_scroll', 'mce-responses', 'mce-error-response', 'mce-success-response']
#
# https://www.diecastmodels.co.nz/
# ['Add "Ottomobile 1/18 Toyota Celica GT-4 (ST165) Tour de Corse 1991" to your cart', 'Add "Ottomobile 1/18 Mazda MX-5 NA" to your cart', 'Add "GT Spirit 1/18 1974 Porsche 911 3.0 RS Birch Green" to your cart', 'Add "GT Spirit 1/18 1991 Porsche 911 (964) Turbo 3.3 Coupe" to your cart', 'Add "Diecast Models $40 Gift Voucher" to your cart', 'Add "Golden Wheel 1/18 1940 Ford Delivery Van - Goodyear" to your cart', 'Add "Golden Wheel 1/18 1940 Ford Tanker - Goodyear" to your cart']
# ['shop-cart']
#
# ['sidecart', 'Form_search_q_Holder', 'Form_search_ParentID_Holder', 'Form_search_ScaleID_Holder', 'Form_search_ManufacturerID_Holder', 'mc_embed_signup', 'mc_embed_signup_scroll', 'mce-responses', 'mce-error-response', 'mce-success-response']

# %% [markdown]
# ## Detect card payment options - Visa, Mastercard etc.

# %%
def has_card_detector(html):
    bs = BeautifulSoup(html)
    
    if 'addtocart' in html.lower():
        return True
    elif any(tag['href'] for tag in bs.find_all('a', {'href': True}) if 'payment' in tag['href']):
        return True
    elif any('payment' in tag_class for tag in bs.find_all('li', {'class': True}) for tag_class in tag['class']):
        return True
    
    return False

def payment_system_detector(html):
    payment_names = ['visa','mastercard','amex','applepay','afterpay','zippay',
                     'alipay','klarna']
    
    html_lower = html.lower()
    detected_cards = [
        payment_name for payment_name in payment_names
        if payment_name in html_lower
    ]
    
    return detected_cards


card = pd.DataFrame(
    [(make_url_name(site), site) for site in actual.keys()],
    columns=['name', 'url']
)
card['has_card'] = [has_card_detector(site_to_html[site]) if site not in scrape_errors else False for site in card['url']]
card['payment_names'] = [payment_system_detector(site_to_html[site]) if site not in scrape_errors else [] for site in card['url']]

card[card['has_card']]
# Out:
#                   name                                url  has_card  \
# 1               huffer          https://www.huffer.co.nz/      True
# 2             allbirds         https://www.allbirds.co.nz      True
# 3     infinitedefinite      https://infinitedefinite.com/      True
# 4         hallensteins      https://www.hallensteins.com/      True
# 5             glassons        https://www.glassons.com/nz      True
# ..                 ...                                ...       ...
# 134             amoodz            https://www.amoodz.com/      True
# 135  smallchangefinery  http://www.smallchangefinery.com/      True
# 138           kerripom          https://www.kerripom.com/      True
# 140       tarotbyseven      https://www.tarotbyseven.com/      True
# 141    theguitarhanger   https://www.theguitarhanger.com/      True
#
#                                          payment_names
# 1                                                   []
# 2                                           [afterpay]
# 3                                                   []
# 4    [visa, mastercard, amex, applepay, afterpay, a...
# 5                   [visa, mastercard, amex, afterpay]
# ..                                                 ...
# 134                                 [visa, mastercard]
# 135                                                 []
# 138                                                 []
# 140                                                 []
# 141                                                 []
#
# [68 rows x 4 columns]

# %%
sum(['addtocart' in site_to_html[site].lower() for site in card['url'] if site not in scrape_errors])
# Out:
# 58

# %%
sum([any(tag['href'] for tag in BeautifulSoup(site_to_html[site]).find_all('a', {'href': True}) if 'payment' in tag['href']) 
     for site in card['url'] if site not in scrape_errors])
# Out:
# 12

# %%
sum([any('payment' in tag_class for tag in BeautifulSoup(site_to_html[site]).find_all('li', {'class': True}) for tag_class in tag['class']) 
     for site in card['url'] if site not in scrape_errors])
# Out:
# 9

# %%
# See which sites do not have any payment info. detected (ie. no cart software, custom cart or payment system detected)
test = results.merge(card, how='inner', left_on=['name','url'], right_on=['name','url'])
test[~np.logical_or(np.logical_or(test['pred'].apply(len) > 0, test['has_card']), test['payment_names'].apply(len) > 0)]
# Out:
#                      name                                   url  \
# 7               countdown         https://shop.countdown.co.nz/
# 9        picspeanutbutter  https://www.picspeanutbutter.com/nz/
# 10   rainbowconfectionery   https://rainbowconfectionery.co.nz/
# 23              justjeans          https://www.justjeans.co.nz/
# 41                   nike              https://www.nike.com/nz/
# 43                  kmart              https://www.kmart.co.nz/
# 44                farmers            https://www.farmers.co.nz/
# 50                 pbtech             https://www.pbtech.co.nz/
# 52                ebgames            https://www.ebgames.co.nz/
# 53              dicksmith          https://www.dicksmith.co.nz/
# 54                   etsy                 https://www.etsy.com/
# 55             aliexpress           https://www.aliexpress.com/
# 56                 amazon               https://www.amazon.com/
# 58                  1-day              https://www.1-day.co.nz/
# 59              themarket             https://themarket.com/nz/
# 71          plasticmodels      https://www.plasticmodels.co.nz/
# 72          diecastmodels      https://www.diecastmodels.co.nz/
# 77          buddhibaby.ca                 http://buddhibaby.ca/
# 81               bestfive              https://bestfive.com.au/
# 96              brilliant                https://brilliant.org/
# 107           hellyhansen          https://www.hellyhansen.com/
# 114     thehatchinstitute         http://thehatchinstitute.org/
# 131        vintique-watch       https://www.vintique-watch.com/
#
#                 BuiltWith pred Correct Partial_correct           Exception  \
# 7                [custom]   []   False           False
# 9                     [?]   []
# 10              [Magento]   []   False           False
# 23   [Kibo, HCL Commerce]   []   False           False
# 41                    [?]   []
# 43         [HCL Commerce]   []   False           False
# 44            [Intershop]   []   False           False
# 50               [custom]        False           False  UnicodeDecodeError
# 52               [custom]   []   False           False          robotblock
# 53                    [?]   []                                  robotblock
# 54               [custom]   []   False           False
# 55               [custom]   []   False           False
# 56      [Amazon Webstore]   []   False           False
# 58               [custom]   []   False           False
# 59                    [?]   []
# 71               [custom]   []   False           False
# 72               [custom]   []   False           False
# 77                    [?]   []
# 81                [!none]   []   False           False
# 96                    [?]   []
# 107       [Magento, Kibo]   []   False           False
# 114                   [?]   []
# 131                   [?]                                         SSLError
#
#      has_card payment_names
# 7       False            []
# 9       False            []
# 10      False            []
# 23      False            []
# 41      False            []
# 43      False            []
# 44      False            []
# 50      False            []
# 52      False            []
# 53      False            []
# 54      False            []
# 55      False            []
# 56      False            []
# 58      False            []
# 59      False            []
# 71      False            []
# 72      False            []
# 77      False            []
# 81      False            []
# 96      False            []
# 107     False            []
# 114     False            []
# 131     False            []

# %%
test[test['Exception'] != ""]
# Out:
#                name                              url BuiltWith pred Correct  \
# 50           pbtech        https://www.pbtech.co.nz/  [custom]        False
# 52          ebgames       https://www.ebgames.co.nz/  [custom]   []   False
# 53        dicksmith     https://www.dicksmith.co.nz/       [?]   []
# 131  vintique-watch  https://www.vintique-watch.com/       [?]
#
#     Partial_correct           Exception  has_card payment_names
# 50            False  UnicodeDecodeError     False            []
# 52            False          robotblock     False            []
# 53                           robotblock     False            []
# 131                            SSLError     False            []
